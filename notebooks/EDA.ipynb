# %%
# %run '../src/visualizations/eda.py'

# %%
load_color_palette(['#0c343d', '#00c3b1', '#cc4125'])

# %%
all_file_paths = load_paths()

# %%
visualize_image_split(all_file_paths)
# Out:
# There are 12362 images of covered faces in the train folder.
# There are 12338 images of incorrect faces in the train folder.
# There are 12800 images of uncovered faces in the train folder.
# There are 3863 images of covered faces in the holdout folder.
# There are 3856 images of incorrect faces in the holdout folder.
# There are 4000 images of uncovered faces in the holdout folder.
# There are 3090 images of covered faces in the validation folder.
# There are 3084 images of incorrect faces in the validation folder.
# There are 3199 images of uncovered faces in the validation folder.

# %%
visualize_image(all_file_paths)
# Out:
# There are 19315 images of covered faces in the folder.
# There are 19278 images of incorrect faces in the folder.
# There are 19999 images of uncovered faces in the folder.

# %%
incorrect_folders = get_incorrect_folders()

# %%
visualize_stats_split(incorrect_folders)
# Out:
# There are 10184 images of *Mask_Mouth_Chin.jpg in the train folder
# There are 3192 images of *Mask_Mouth_Chin.jpg in the holdout folder
# There are 2580 images of *Mask_Mouth_Chin.jpg in the validation folder
# There are 1154 images of *Mask_Nose_Mouth.jpg in the train folder
# There are 352 images of *Mask_Nose_Mouth.jpg in the holdout folder
# There are 274 images of *Mask_Nose_Mouth.jpg in the validation folder
# There are 1000 images of *Mask_Chin.jpg in the train folder
# There are 312 images of *Mask_Chin.jpg in the holdout folder
# There are 230 images of *Mask_Chin.jpg in the validation folder

# %%
visualize_stats(incorrect_folders)
# Out:
# There are 1542 images of Chin faces in the folder.
# There are 15956 images of Mouth Chin faces in the folder.
# There are 1780 images of Nose Mouth faces in the folder.
