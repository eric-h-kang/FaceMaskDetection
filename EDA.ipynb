# %%
from PIL import Image
path = '/datasets/MaskedFace-Net/train/covered/14931_Mask.jpg'
pil_im = Image.open(path)

# %%
pil_im = Image.open(path)

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024 at 0x7F7F8C06C090>
